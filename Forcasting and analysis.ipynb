# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\minds\Downloads\1644992506125_1644992504891_Excel Sample_BA (1) (1).xlsx',header=1)

# %%
df.head()
# Out:
#    Unnamed: 0       Date  New Installs   Returning Users   Uninstalls   \
# 0         NaN 2021-09-01           6012               715         2538
# 1         NaN 2021-09-02           9327               617         2364
# 2         NaN 2021-09-03          10415               786         1552
# 3         NaN 2021-09-04          12312               765         2736
# 4         NaN 2021-09-05          15719               944         3288
#
#    Net new installs   Uninstall rate   DAU   Unique Page Views  \
# 0               4738        0.422156  13421               4098
# 1               5725        0.253458  15858               5068
# 2               6222        0.149016  15832               4669
# 3               6258        0.222222  17144               5023
# 4               5532        0.209174  18753               4599
#
#    Page view conversion  Add to Cart  A2C Conv  AddtoCart (Prod page)  \
# 0              0.305342         1316  0.098055               0.321132
# ...

# %%
6012-2538#net new installs wrong
# Out:
# 3474

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'New Installs ', 'Returning Users ',
#        'Uninstalls ', 'Net new installs ', 'Uninstall rate', 'DAU ',
#        'Unique Page Views', 'Page view conversion', 'Add to Cart', 'A2C Conv',
#        'AddtoCart (Prod page)', 'Order Comp', 'Overall Conv', 'Week'],
#       dtype='object')

# %%
df['Net new install rate_1']=df['New Installs ']-df['Uninstalls ']

# %%
2538/(6012)#unistall rate true
# Out:
# 0.4221556886227545

# %%
4098/13421#page view conversion true
# Out:
# 0.3053423738916623

# %%
1316/13421#A2C conversion true
# Out:
# 0.09805528649131957

# %%
460/13421#overall conversion true
# Out:
# 0.034274644214291036

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             0 non-null      float64
#  1   Date                   112 non-null    datetime64[ns]
#  2   New Installs           112 non-null    int64
#  3   Returning Users        112 non-null    int64
#  4   Uninstalls             112 non-null    int64
#  5   Net new installs       112 non-null    int64
#  6   Uninstall rate         112 non-null    float64
#  7   DAU                    112 non-null    int64
#  8   Unique Page Views      112 non-null    int64
#  9   Page view conversion   112 non-null    float64
#  10  Add to Cart            112 non-null    int64
#  11  A2C Conv               112 non-null    float64
#  12  AddtoCart (Prod page)  112 non-null    float64
#  13  Order Comp             112 non-null    int64
# ...

# %%
#date,new installs,returning users,uninstalls,net new installs,uninstall rate,unique page views,page view conversion, add to cart,A2C conv,add to cart(prod page),overall conv
#DAU,order comp

# %%
df.describe().T
# Out:
#                        count          mean          std           min  \
# Unnamed: 0               0.0           NaN          NaN           NaN
# New Installs           112.0  12236.267857  3901.796555   4709.000000
# Returning Users        112.0   1075.285714   347.313043    435.000000
# Uninstalls             112.0   3281.258929  1351.596878    970.000000
# Net new installs       112.0   7384.741071  2127.472373   3416.000000
# Uninstall rate         112.0      0.278487     0.102674      0.130152
# DAU                    112.0  21885.580357  6146.255215  11342.000000
# Unique Page Views      112.0   6212.723214  1989.873558   3256.000000
# Page view conversion   112.0      0.285406     0.049519      0.163178
# Add to Cart            112.0   1618.160714   610.822405    704.000000
# A2C Conv               112.0      0.073822     0.016065      0.043668
# AddtoCart (Prod page)  112.0      0.260497     0.044942      0.156836
# ...

# %%
df['Order Comp'].nunique()
# Out:
# 99

# %%
df['Date']
# Out:
# 0     2021-09-01
# 1     2021-09-02
# 2     2021-09-03
# 3     2021-09-04
# 4     2021-09-05
#          ...
# 107   2021-12-17
# 108   2021-12-18
# 109   2021-12-19
# 110   2021-12-20
# 111   2021-12-21
# Name: Date, Length: 112, dtype: datetime64[ns]

# %%
df['Week']=pd.to_datetime(df.Date).dt.week
# Out:
# C:\Users\minds\AppData\Local\Temp\ipykernel_27796\1592650447.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['Week']=pd.to_datetime(df.Date).dt.week

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'New Installs ', 'Returning Users ',
#        'Uninstalls ', 'Net new installs ', 'Uninstall rate', 'DAU ',
#        'Unique Page Views', 'Page view conversion', 'Add to Cart', 'A2C Conv',
#        'AddtoCart (Prod page)', 'Order Comp', 'Overall Conv', 'Week'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.lineplot(x='Date',y='Net new installs ',ci=None,data=df)
ax.set_title('Lineplot:returning users')
# Out:
# Text(0.5, 1.0, 'Lineplot:returning users')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.lineplot(x='Date',y='DAU ',ci=None,data=df)
ax.set_title('Lineplot:daily active user')
# Out:
# Text(0.5, 1.0, 'Lineplot:daily active user')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.lineplot(x='Date',y='Page view conversion',ci=None,data=df)
ax.set_title('Lineplot:Page view conversion')
# Out:
# Text(0.5, 1.0, 'Lineplot:Page view conversion')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.lineplot(x='Date',y='A2C Conv',ci=None,data=df)
ax.set_title('Lineplot:A2C Conv')
# Out:
# Text(0.5, 1.0, 'Lineplot:A2C Conv')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.lineplot(x='Date',y='Overall Conv',ci=None,data=df)
ax.set_title('Lineplot:Overall Conv')
# Out:
# Text(0.5, 1.0, 'Lineplot:Overall Conv')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.barplot(x='Week',y='Overall Conv',ci=None,data=df)
ax.set_title('Barplot:Overall Conv')
# Out:
# Text(0.5, 1.0, 'Barplot:Overall Conv')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.scatterplot(x='Date',y='Overall Conv',ci=None,data=df)
ax.set_title('Scatterplot:Overall Conv')
# Out:
# Text(0.5, 1.0, 'Scatterplot:Overall Conv')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.regplot(x='Week',y='Overall Conv',data=df)
ax.set_title('Regressionplot:Overall Conv')
# Out:
# Text(0.5, 1.0, 'Regressionplot:Overall Conv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'New Installs ', 'Returning Users ',
#        'Uninstalls ', 'Net new installs ', 'Uninstall rate', 'DAU ',
#        'Unique Page Views', 'Page view conversion', 'Add to Cart', 'A2C Conv',
#        'AddtoCart (Prod page)', 'Order Comp', 'Overall Conv', 'Week'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
#lineplot
ax=sns.scatterplot(x='Order Comp',y='Overall Conv',hue='Week',ci=None,data=df)
ax.set_title('Scatterplot:Overall Conv')
# Out:
# Text(0.5, 1.0, 'Scatterplot:Overall Conv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                112
# Date                        0
# New Installs                0
# Returning Users             0
# Uninstalls                  0
# Net new installs            0
# Uninstall rate              0
# DAU                         0
# Unique Page Views           0
# Page view conversion        0
# Add to Cart                 0
# A2C Conv                    0
# AddtoCart (Prod page)       0
# Order Comp                  0
# Overall Conv                0
# Week                        0
# Net new install rate_1      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'New Installs ', 'Returning Users ',
#        'Uninstalls ', 'Net new installs ', 'Uninstall rate', 'DAU ',
#        'Unique Page Views', 'Page view conversion', 'Add to Cart', 'A2C Conv',
#        'AddtoCart (Prod page)', 'Order Comp', 'Overall Conv', 'Week',
#        'Net new install rate_1'],
#       dtype='object')

# %%
df1 = df[['Date','Net new install rate_1','DAU ','Page view conversion','A2C Conv','Overall Conv','Week']]
df1.head()
# Out:
#         Date  Net new install rate_1   DAU   Page view conversion  A2C Conv  \
# 0 2021-09-01                    3474  13421              0.305342  0.098055
# 1 2021-09-02                    6963  15858              0.319586  0.082797
# 2 2021-09-03                    8863  15832              0.294909  0.076680
# 3 2021-09-04                    9576  17144              0.292989  0.077462
# 4 2021-09-05                   12431  18753              0.245241  0.074281
#
#    Overall Conv  Week
# 0      0.034275    35
# 1      0.032854    35
# 2      0.019644    35
# 3      0.025373    35
# 4      0.023356    35

# %%
# trend = df1.rolling(
#     window=365,
#     center=True,
#     min_periods=183,
# ).mean()

# %%
# correlation plot
corr = df1.corr()
sns.heatmap(corr, cmap = 'Wistia', annot= True);

# %%
import numpy as np

# %%
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df1['Net new install rate_1'],bins=50,color='r',ax=ax)
ax.set_title('Distribution')

ax=f.add_subplot(122)
sns.distplot(np.log10(df1['Net new install rate_1']),bins=40,color='b',ax=ax)
ax.set_title('Distribution in $log$ sacle')
ax.set_xscale('log');
# Out:
# C:\Users\minds\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\minds\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df1)

# %%
# !pip install prophet#using prophet for forecasting
# Out:
# ...
#   Created wheel for pymeeus: filename=PyMeeus-0.5.11-py3-none-any.whl size=730985 sha256=8c5c67d493c49682a4766acd03e4bc5c514abbf0d1d0224d5b72fd1dac2f4ed4
#   Stored in directory: c:\users\minds\appdata\local\pip\cache\wheels\33\3d\82\4579e9cca41ff991140b2e050bc6df3a38292f26e4fa06b15d
# Successfully built pymeeus
# ...

# %%
from prophet import Prophet

# %%
df1.columns
# Out:
# Index(['Date', 'Net new install rate_1', 'DAU ', 'Page view conversion',
#        'A2C Conv', 'Overall Conv', 'Week'],
#       dtype='object')

# %%
df2=df1[['Date','Net new install rate_1']]

# %%
df2.head()
# Out:
#         Date  Net new install rate_1
# 0 2021-09-01                    3474
# 1 2021-09-02                    6963
# 2 2021-09-03                    8863
# 3 2021-09-04                    9576
# 4 2021-09-05                   12431

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    112 non-null    datetime64[ns]
#  1   Net new install rate_1  112 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.9 KB

# %%
p = Prophet(interval_width=0.92, daily_seasonality=True)

# %%
df2.columns = ['ds', 'y']
df2.head()
# Out:
#           ds      y
# 0 2021-09-01   3474
# 1 2021-09-02   6963
# 2 2021-09-03   8863
# 3 2021-09-04   9576
# 4 2021-09-05  12431

# %%
model = p.fit(df2)
# Out:
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = p.make_future_dataframe(periods=10, freq='D')
future.tail()
# Out:
#             ds
# 117 2021-12-27
# 118 2021-12-28
# 119 2021-12-29
# 120 2021-12-30
# 121 2021-12-31

# %%
forecast_prediction = p.predict(future)
forecast_prediction.tail()
# Out:
#             ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 117 2021-12-27   9865.814100  7969.560610  18510.773060   9865.707156
# 118 2021-12-28   9915.858714  6878.148835  16817.259906   9915.729384
# 119 2021-12-29   9965.903327  5769.971084  16127.162931   9965.746456
# 120 2021-12-30  10015.947941  6008.358249  16531.150000  10015.755899
# 121 2021-12-31  10065.992555  8003.077051  18106.260562  10065.765854
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 117   9865.891884     3233.410602           3233.410602           3233.410602
# 118   9915.957879     1995.721071           1995.721071           1995.721071
# 119   9966.025994     1145.540693           1145.540693           1145.540693
# 120  10016.093520     1620.584562           1620.584562           1620.584562
# 121  10066.163240     2944.102486           2944.102486           2944.102486
#
#            daily  daily_lower  daily_upper       weekly  weekly_lower  \
# ...

# %%
plot1 = p.plot(forecast_prediction)##forcast

# %%
forecast_prediction.head()#y hat is out net install prediction
# Out:
#           ds        trend   yhat_lower    yhat_upper  trend_lower  \
# 0 2021-09-01  4009.614980    30.459881  10079.533203  4009.614980
# 1 2021-09-02  4059.904452   417.965576  11101.391888  4059.904452
# 2 2021-09-03  4110.193924  1746.323117  12470.515745  4110.193924
# 3 2021-09-04  4160.483396  1346.599438  11336.453614  4160.483396
# 4 2021-09-05  4210.772867   955.674461  11276.500146  4210.772867
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  4009.614980     1145.540693           1145.540693           1145.540693
# 1  4059.904452     1620.584562           1620.584562           1620.584562
# 2  4110.193924     2944.102486           2944.102486           2944.102486
# 3  4160.483396     2063.896567           2063.896567           2063.896567
# 4  4210.772867     2078.845258           2078.845258           2078.845258
#
#          daily  daily_lower  daily_upper       weekly  weekly_lower  \
# ...

# %%
forecast_prediction.tail(10)
##prediction
# Out:
#             ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 112 2021-12-22   9615.591031  5122.881498  16167.876678   9615.586147
# 113 2021-12-23   9665.635645  6157.666850  16418.362556   9665.618963
# 114 2021-12-24   9715.680259  7987.868599  17715.005672   9715.647601
# 115 2021-12-25   9765.724872  6560.495698  16677.722165   9765.671549
# 116 2021-12-26   9815.769486  6698.913479  17297.026622   9815.690395
# 117 2021-12-27   9865.814100  7969.560610  18510.773060   9865.707156
# 118 2021-12-28   9915.858714  6878.148835  16817.259906   9915.729384
# 119 2021-12-29   9965.903327  5769.971084  16127.162931   9965.746456
# 120 2021-12-30  10015.947941  6008.358249  16531.150000  10015.755899
# 121 2021-12-31  10065.992555  8003.077051  18106.260562  10065.765854
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 112   9615.595626     1145.540693           1145.540693           1145.540693
# ...

# %%
prediction=forecast_prediction[['ds','yhat']]
prediction.tail()
